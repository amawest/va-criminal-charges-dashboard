# %%
import pandas as pd

# %%
x_2010 = pd.read_csv('2010_disparities.csv')
x_2011 = pd.read_csv('2011_disparities.csv')
x_2012 = pd.read_csv('2012_disparities.csv')
x_2013 = pd.read_csv('2013_disparities.csv')
x_2014 = pd.read_csv('2014_disparities.csv')
x_2015 = pd.read_csv('2015_disparities.csv')
x_2016 = pd.read_csv('2016_disparities.csv')
x_2017 = pd.read_csv('2017_disparities.csv')
x_2018 = pd.read_csv('2018_disparities.csv')
x_2019 = pd.read_csv('2019_disparities.csv')

# %%
x_2010['year'] = 2010
x_2011['year'] = 2011
x_2012['year'] = 2012
x_2013['year'] = 2013
x_2014['year'] = 2014
x_2015['year'] = 2015
x_2016['year'] = 2016
x_2017['year'] = 2017
x_2018['year'] = 2018
x_2019['year'] = 2019

# %%
x_2010.to_csv('fin_2010_disparities.csv')
x_2011.to_csv('fin_2011_disparities.csv')
x_2012.to_csv('fin_2012_disparities.csv')
x_2013.to_csv('fin_2013_disparities.csv')
x_2014.to_csv('fin_2014_disparities.csv')
x_2015.to_csv('fin_2015_disparities.csv')
x_2016.to_csv('fin_2016_disparities.csv')
x_2017.to_csv('fin_2017_disparities.csv')
x_2018.to_csv('fin_2018_disparities.csv')
x_2019.to_csv('fin_2019_disparities.csv')

# %%
files = ['fin_2010_disparities.csv',
         'fin_2011_disparities.csv',
         'fin_2012_disparities.csv',
         'fin_2013_disparities.csv',
         'fin_2014_disparities.csv',
         'fin_2015_disparities.csv',
         'fin_2016_disparities.csv',
         'fin_2017_disparities.csv',
         'fin_2018_disparities.csv',
         'fin_2019_disparities.csv'
         ]

# %%
dfs = [pd.read_csv(f, sep=",") for f in files]

# %%
all_files = pd.concat(dfs,ignore_index=True)

# %%
del all_files['Unnamed: 0']

# %%
all_files
# Out:
#       fips              CTYNAME  Percent_Overall  Disparity_White_Male  \
# 0        1      Accomack County            0.661                -0.017
# 1        3     Albemarle County            0.400                 0.045
# 2        5     Alleghany County            2.142                 0.354
# 3        7        Amelia County            1.357                 0.305
# 4        9       Amherst County            0.902                 0.087
# ...    ...                  ...              ...                   ...
# 1325   800         Suffolk city            1.978                -1.098
# 1326   810  Virginia Beach city            0.964                -0.162
# 1327   820      Waynesboro city            5.440                -3.481
# 1328   830    Williamsburg city           10.726                -5.257
# 1329   840      Winchester city            4.723                -2.896
#
#       Disparity_White_Female  Disparity_Black_Male  Disparity_Black_Female  \
# ...

# %%
all_files.to_csv('all_marijunana_files.csv')
